# %%
import bioframe as bf
import pandas as pd
from glob import glob

# %%
data_path = '/scratch/groups/horence/angelika/EM_expression/data/'

# %%
glob(data_path+'*')
# Out:
# ['/scratch/groups/horence/angelika/EM_expression/data/iso',
#  '/scratch/groups/horence/angelika/EM_expression/data/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_exon_reads.parquet',
#  '/scratch/groups/horence/angelika/EM_expression/data/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_reads.gct.gz',
#  '/scratch/groups/horence/angelika/EM_expression/data/gencode.v38.annotation.gff3.gz',
#  '/scratch/groups/horence/angelika/EM_expression/data/GTEx_Analysis_2017-06-05_v8_STARv2.5.3a_junctions.gct.gz']

# %%
mrna = bf.UCSCClient('hg38').fetch_mrna()

# %%
mrna.columns
# Out:
# Index(['bin', 'matches', 'misMatches', 'repMatches', 'nCount', 'qNumInsert',
#        'qBaseInsert', 'tNumInsert', 'tBaseInsert', 'strand', 'qName', 'qSize',
#        'qStart', 'qEnd', 'tName', 'tSize', 'tStart', 'tEnd', 'blockCount',
#        'blockSizes', 'qStarts', 'tStarts'],
#       dtype='object')

# %%
mrna
# Out:
#           bin  matches  misMatches  repMatches  nCount  qNumInsert  \
# 0         585     1579          25           0       0           0
# 1         585     1419          21           0       0           0
# 2         585     1533          12           0       0           0
# 3         585     1578          27           0       0           0
# 4         585     1652           0           0       0           0
# ...       ...      ...         ...         ...     ...         ...
# 10489974  587      298           4           0       0           0
# 10489975  587      272           4           0       0           0
# 10489976  588      280           7           0       0           0
# 10489977  588      283           3           0       0           0
# 10489978  703     2427           0           0       0           0
#
#           qBaseInsert  tNumInsert  tBaseInsert strand  ... qStart  qEnd  \
# 0                   0           2          884      +  ...      0  1604
# ...

# %%
mrna.qName
# Out:
# 0           AM992877
# 1           AM992881
# 2           AM992878
# 3           AM992879
# 4           AM992871
#               ...
# 10489974    MT594084
# 10489975    MT594083
# 10489976    MT594099
# 10489977    MT594100
# 10489978    MT505392
# Name: qName, Length: 10489979, dtype: object

# %%
exon_iter = bf.read_parquet(data_path+'GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_exon_reads.parquet', iterator=True)

# %%
help(exon_iter)
# Out:
# Help on ParquetFileIterator in module bioframe.io.fileops object:
#
# class ParquetFileIterator(pyarrow.parquet.ParquetFile)
#  |  ParquetFileIterator(source, metadata=None, common_metadata=None, read_dictionary=None, memory_map=False, buffer_size=0, pre_buffer=False, coerce_int96_timestamp_unit=None)
#  |
#  |  Reader interface for a single Parquet file.
#  |
#  |  Parameters
#  |  ----------
#  |  source : str, pathlib.Path, pyarrow.NativeFile, or file-like object
#  |      Readable source. For passing bytes or buffer-like file containing a
#  |      Parquet file, use pyarrow.BufferReader.
#  |  metadata : FileMetaData, default None
#  |      Use existing metadata object, rather than reading from file.
#  |  common_metadata : FileMetaData, default None
#  |      Will be used in reads for pandas schema metadata if not found in the
#  |      main file's metadata, no other uses at the moment.
#  |  memory_map : bool, default False
# ...

# %%
for i, exon in enumerate(exon_iter):
#     if i > 2:
#         break
    print(i)

# %%
pd.read_parquet(data_path+'GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_exon_reads.parquet')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21468/3721956427.py in <module>
# ----> 1 pd.read_parquet(data_path+'GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_exon_reads.parquet')
#
# ~/miniconda3/envs/rna/lib/python3.8/site-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     493     impl = get_engine(engine)
#     494
# --> 495     return impl.read(
#     496         path,
#     497         columns=columns,
#
# ~/miniconda3/envs/rna/lib/python3.8/site-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     237         )
#     238         try:
# --> 239             result = self.api.parquet.read_table(
#     240                 path_or_handle, columns=columns, **kwargs
#     241             ).to_pandas(**to_pandas_kwargs)
#
# ...
